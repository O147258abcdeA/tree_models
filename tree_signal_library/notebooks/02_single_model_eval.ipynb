# %% [markdown]
# # 02 单模型信号评估
#
# 查看 model_summary、IC 时间序列、分组收益、多空净值。

# %%
import sys; sys.path.insert(0, '..')
import polars as pl
from src.utils.config import load_config
scfg = load_config('signal_config.yaml')

# %%
# summary = pl.read_csv('../data/reports/model_summary.csv')
# summary.sort('rank_icir', descending=True)

# %%
# ic = pl.read_parquet('../data/reports/ic_timeseries.parquet')
# ic.group_by('model_name').agg(pl.col('ic').mean(), pl.col('rank_ic').mean())
