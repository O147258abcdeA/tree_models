# %% [markdown]
# # 03 多模型信号融合
#
# 对比 equal_rank / icir_weighted / stacking 融合信号的 IC 与多空表现。

# %%
import sys; sys.path.insert(0, '..')
import polars as pl
from src.utils.config import load_config
from src.signals.signal_ensemble import run_ensemble
ecfg = load_config('ensemble_config.yaml')

# %%
# signals = pl.read_parquet('../data/signals/processed/**/*.parquet')
# ens, weights = run_ensemble(signals, ecfg, returns, horizon=5)
