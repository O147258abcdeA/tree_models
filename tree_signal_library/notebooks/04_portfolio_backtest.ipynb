# %% [markdown]
# # 04 组合回测
#
# 中证1000指数增强与多空策略回测结果分析。

# %%
import sys; sys.path.insert(0, '..')
import polars as pl
from src.utils.config import load_config
pcfg = load_config('portfolio_config.yaml')

# %%
# daily = pl.read_parquet('../data/reports/long_short_daily.parquet')
# (1 + daily['ls_ret_net']).cum_prod()
