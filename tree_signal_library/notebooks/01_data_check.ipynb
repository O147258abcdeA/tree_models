# %% [markdown]
# # 01 数据检查
#
# 检查原始因子库：日期覆盖、每日股票数、因子缺失率、universe 过滤效果。

# %%
import sys; sys.path.insert(0, '..')
import polars as pl
from src.utils.config import load_config
from src.data.load_data import load_factor_data, get_factor_cols, iter_dates
cfg = load_config('data_config.yaml')

# %%
# 交易日与覆盖率
# dates = iter_dates('../' + cfg['raw_path'])
# print(len(dates), dates[:3], dates[-3:])

# %%
# 单日横截面与缺失率
# from src.data.load_data import get_factor
# from src.data.preprocess import compute_missing_rate
# day = get_factor(dates[0], '../' + cfg['raw_path'])
# rates = compute_missing_rate(day, get_factor_cols(day))
# pl.DataFrame({'factor': list(rates), 'missing': list(rates.values())}).sort('missing', descending=True).head(20)
